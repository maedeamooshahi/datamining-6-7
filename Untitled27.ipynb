# %% [markdown]
# <a href="https://colab.research.google.com/github/maedeamooshahi/datamining-6-7/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ایمپورت کتابخانه های لازم

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Dense, Flatten, LSTM, MaxPooling1D, Bidirectional
from keras import backend as K

# %% [markdown]
# بارگذاری فایل اموزشی و نمایش آن

# %%
train=pd.read_csv('/content/train.csv')
train
# Out:
#        Column1                                            comment  label  \
# 0            0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD
# 1            1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY
# 2            2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD
# 3            3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY
# 4            4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY
# ...        ...                                                ...    ...
# 56695    56695  یک تیکه کم فرستاده بودن و با تماس من در کمترین...  HAPPY
# 56696    56696  عالی بود همه چیز ممنونم پیک هم خیلی مرتب و به ...  HAPPY
# 56697    56697  مثل همیشه عالی، من چندمین باره سفارش میدم و هر...  HAPPY
# 56698    56698      دلستر استوایی خواسته بودم اما لیمویی فرستادند  HAPPY
# 56699    56699  جای مرغ گریل شده ناگت بود، به این نمی‌گن چیکن ...    SAD
#
#        label_id
# 0             1
# 1             0
# 2             1
# 3             0
# ...

# %%
train.drop(['Column1','label'], inplace=True,axis=1)
train
# Out:
#                                                  comment  label_id
# 0        واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح         1
# 1      قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...         0
# 2      قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...         1
# 3      عالللی بود همه چه درست و به اندازه و کیفیت خوب...         0
# 4                          شیرینی وانیلی فقط یک مدل بود.         0
# ...                                                  ...       ...
# 56695  یک تیکه کم فرستاده بودن و با تماس من در کمترین...         0
# 56696  عالی بود همه چیز ممنونم پیک هم خیلی مرتب و به ...         0
# 56697  مثل همیشه عالی، من چندمین باره سفارش میدم و هر...         0
# 56698      دلستر استوایی خواسته بودم اما لیمویی فرستادند         0
# 56699  جای مرغ گریل شده ناگت بود، به این نمی‌گن چیکن ...         1
#
# [56700 rows x 2 columns]

# %% [markdown]
# devبارگذاری فایل

# %%
dev=pd.read_csv('/content/dev.csv')
dev
# Out:
#       Column1                                            comment  label  \
# 0           0  همه ساندویچ‌ها سرد بود متاسفانه در صورتی که فا...    SAD
# 1           1                             تشکر، عالی‌تر از همیشه  HAPPY
# 2           2  مرغ و کدو رو دوس نداشتم ولی کلا ساندویچهای خوش...  HAPPY
# 3           3     نمیدونم هزینه بسته بندی به چه دلیل گرفته شد؟؟؟    SAD
# 4           4  یک نوشابه کم ارسال شد و تاخیر فراوان و غذای نس...    SAD
# ...       ...                                                ...    ...
# 6295     6295  سلام من به فاکتور غذاهایی که سفارش میدم احتیاج...    SAD
# 6296     6296  سایز پیتزا نسبت به سفارشاتی که قبلا گذشتم کم ش...    SAD
# 6297     6297  من قارچ اضافه رو اضافه کرده بودم بودم اما اگر ...  HAPPY
# 6298     6298  همرو بعد ۲ساعت تاخیر اشتباه آوردن پولشم رفت رو...    SAD
# 6299     6299                             فلفلش خییییلی تند بود.  HAPPY
#
#       label_id
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ...

# %% [markdown]
# نمایش فایل اعتبار سنجی

# %%
dev.drop(['Column1','label'], inplace=True,axis=1)
dev
# Out:
#                                                 comment  label_id
# 0     همه ساندویچ‌ها سرد بود متاسفانه در صورتی که فا...         1
# 1                                تشکر، عالی‌تر از همیشه         0
# 2     مرغ و کدو رو دوس نداشتم ولی کلا ساندویچهای خوش...         0
# 3        نمیدونم هزینه بسته بندی به چه دلیل گرفته شد؟؟؟         1
# 4     یک نوشابه کم ارسال شد و تاخیر فراوان و غذای نس...         1
# ...                                                 ...       ...
# 6295  سلام من به فاکتور غذاهایی که سفارش میدم احتیاج...         1
# 6296  سایز پیتزا نسبت به سفارشاتی که قبلا گذشتم کم ش...         1
# 6297  من قارچ اضافه رو اضافه کرده بودم بودم اما اگر ...         0
# 6298  همرو بعد ۲ساعت تاخیر اشتباه آوردن پولشم رفت رو...         1
# 6299                             فلفلش خییییلی تند بود.         0
#
# [6300 rows x 2 columns]

# %%
train=train.drop_duplicates(subset=None, keep='first', inplace=False)
train
# Out:
#                                                  comment  label_id
# 0        واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح         1
# 1      قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...         0
# 2      قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...         1
# 3      عالللی بود همه چه درست و به اندازه و کیفیت خوب...         0
# 4                          شیرینی وانیلی فقط یک مدل بود.         0
# ...                                                  ...       ...
# 56695  یک تیکه کم فرستاده بودن و با تماس من در کمترین...         0
# 56696  عالی بود همه چیز ممنونم پیک هم خیلی مرتب و به ...         0
# 56697  مثل همیشه عالی، من چندمین باره سفارش میدم و هر...         0
# 56698      دلستر استوایی خواسته بودم اما لیمویی فرستادند         0
# 56699  جای مرغ گریل شده ناگت بود، به این نمی‌گن چیکن ...         1
#
# [56696 rows x 2 columns]

# %% [markdown]
# توکن کردن نظرات

# %%
tokenizer = Tokenizer(num_words = 100000, oov_token='<oov>')
tokenizer.fit_on_texts(train['comment'])

# %%
train_comments=tokenizer.texts_to_sequences(train['comment'])
test_comments=tokenizer.texts_to_sequences(dev['comment'])

training_padded=pad_sequences(train_comments,maxlen=100,truncating='post')
testing_padded=pad_sequences(test_comments,maxlen=100,truncating='post')

# %%
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Dense
covnet = tf.keras.Sequential([
                    tf.keras.layers.Embedding(100000,    32, input_length=100)
                    ])
covnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 32)           3200000
#
# ...
# Total params: 3,200,000
# Trainable params: 3,200,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  word2vecبا روش  embedibg

# %%
covnet.add(Conv1D(32, kernel_size=3, activation='elu', padding='same'))
covnet.add(tf.keras.layers.Flatten())
covnet.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
covnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 32)           3200000
#
#  conv1d (Conv1D)             (None, 100, 32)           3104
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 1)                 3201
#
# ...
# Total params: 3,206,305
# Trainable params: 3,206,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
covnet.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# آموزش مدل برای چند دوره

# %%
history =covnet.fit(training_padded, train['label_id'], epochs=10, validation_data=(testing_padded, dev['label_id']))
# Out:
# Epoch 1/10
# 1772/1772 [==============================] - 74s 42ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 3.0208 - val_accuracy: 0.7546
# Epoch 2/10
# 1772/1772 [==============================] - 73s 41ms/step - loss: 0.0131 - accuracy: 0.9952 - val_loss: 3.0549 - val_accuracy: 0.7557
# Epoch 3/10
# 1772/1772 [==============================] - 73s 41ms/step - loss: 0.0131 - accuracy: 0.9950 - val_loss: 3.0577 - val_accuracy: 0.7594
# Epoch 4/10
# 1772/1772 [==============================] - 74s 42ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 3.3030 - val_accuracy: 0.7527
# Epoch 5/10
# 1772/1772 [==============================] - 73s 41ms/step - loss: 0.0117 - accuracy: 0.9956 - val_loss: 3.1879 - val_accuracy: 0.7606
# Epoch 6/10
# 1772/1772 [==============================] - 74s 42ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 3.2465 - val_accuracy: 0.7584
# Epoch 7/10
# ...

# %% [markdown]
# traning loss و validation loss ترسیم نمودار های

# %%
import matplotlib.pyplot as plt
plt.title('Loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'tset'], loc='upper left')

# %%
import matplotlib.pyplot as plt
plt.title('accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train', 'test'], loc='upper left')
